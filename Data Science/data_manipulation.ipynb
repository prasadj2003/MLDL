# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('universities.csv')

# %%
df.head()
# Out:
#   2026 Rank Previous Rank                             Institution Name  \
# 0         1             1  Massachusetts Institute of Technology (MIT)
# 1         2             2                      Imperial College London
# 2         3             6                          Stanford University
# 3         4             3                         University of Oxford
# 4         5             4                           Harvard University
#
#           Country/Territory    Region Size Focus Research  \
# 0  United States of America  Americas    M    CO       VH
# 1            United Kingdom    Europe    L    FO       VH
# 2  United States of America  Americas    L    FC       VH
# 3            United Kingdom    Europe    L    FC       VH
# 4  United States of America  Americas    L    FC       VH
#
#                    Status  AR SCORE  ... ISR RANK  ISD SCORE ISD RANK  \
# 0  Private not for Profit     100.0  ...      153       92.3      130
# ...

# %%
df.describe()
# Out:
#           AR SCORE     ER SCORE    FSR SCORE    CPF SCORE    IFR SCORE  \
# count  1501.000000  1501.000000  1501.000000  1501.000000  1414.000000
# mean     25.785943    26.944237    33.950433    30.425516    36.305658
# std      24.500905    25.504494    28.440071    29.679882    35.252024
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       8.800000     8.500000    10.800000     6.000000     6.600000
# 50%      16.000000    16.500000    23.500000    18.000000    20.100000
# 75%      32.700000    37.500000    50.500000    49.700000    66.100000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#         ISR SCORE    ISD SCORE    IRN SCORE     EO SCORE    SUS SCORE
# count  1464.00000  1464.000000  1499.000000  1501.000000  1477.000000
# mean     33.32541    34.526981    53.356905    29.989674    51.254367
# std      32.75066    31.108600    28.920632    29.197573    21.266331
# ...

# %%
df.dtypes
# Out:
# 2026 Rank             object
# Previous Rank         object
# Institution Name      object
# Country/Territory     object
# Region                object
# Size                  object
# Focus                 object
# Research              object
# Status                object
# AR SCORE             float64
# AR RANK               object
# ER SCORE             float64
# ER RANK               object
# FSR SCORE            float64
# FSR RANK              object
# CPF SCORE            float64
# CPF RANK              object
# IFR SCORE            float64
# IFR RANK              object
# ISR SCORE            float64
# ISR RANK              object
# ISD SCORE            float64
# ISD RANK              object
# IRN SCORE            float64
# IRN RANK              object
# EO SCORE             float64
# EO RANK               object
# SUS SCORE            float64
# SUS RANK              object
# Overall SCORE         object
# dtype: object

# %% [markdown]
# ### Handling missing values

# %%
df.isnull().any()
# Out:
# 2026 Rank            False
# Previous Rank         True
# Institution Name     False
# Country/Territory    False
# Region               False
# Size                  True
# Focus                False
# Research              True
# Status                True
# AR SCORE             False
# AR RANK              False
# ER SCORE             False
# ER RANK              False
# FSR SCORE            False
# FSR RANK             False
# CPF SCORE            False
# CPF RANK             False
# IFR SCORE             True
# IFR RANK              True
# ISR SCORE             True
# ISR RANK              True
# ISD SCORE             True
# ISD RANK              True
# IRN SCORE             True
# IRN RANK              True
# EO SCORE             False
# EO RANK              False
# SUS SCORE             True
# SUS RANK              True
# Overall SCORE        False
# dtype: bool

# %%
df.isnull().sum()
## It shows the number of missing values
# Out:
# 2026 Rank              0
# Previous Rank        112
# Institution Name       0
# Country/Territory      0
# Region                 0
# Size                   1
# Focus                  0
# Research               1
# Status                47
# AR SCORE               0
# AR RANK                0
# ER SCORE               0
# ER RANK                0
# FSR SCORE              0
# FSR RANK               0
# CPF SCORE              0
# CPF RANK               0
# IFR SCORE             87
# IFR RANK              87
# ISR SCORE             37
# ISR RANK              37
# ISD SCORE             37
# ISD RANK              37
# IRN SCORE              2
# IRN RANK               2
# EO SCORE               0
# EO RANK                0
# SUS SCORE             24
# SUS RANK              24
# Overall SCORE          0
# dtype: int64

# %%
## To fill the missing values

df_filled = df.fillna(0) #-> this will fill the missing values with 0

# %% [markdown]
# ### Filling missing values with mean of the column

# %%
df['Filled_IRN_Score'] = df['IRN SCORE'].fillna(df['IRN SCORE'].mean())
df
# Out:
#      2026 Rank Previous Rank                             Institution Name  \
# 0            1             1  Massachusetts Institute of Technology (MIT)
# 1            2             2                      Imperial College London
# 2            3             6                          Stanford University
# 3            4             3                         University of Oxford
# 4            5             4                           Harvard University
# ...        ...           ...                                          ...
# 1496     1401+     1201-1400                   University of West Bohemia
# 1497     1401+     1201-1400                    Voronezh State University
# 1498     1401+           NaN                          Walailak University
# 1499     1401+     1201-1400                         Yamaguchi University
# 1500     1401+     1201-1400                          Youngsan University
#
#              Country/Territory    Region Size Focus Research  \
# ...

# %%
df.dtypes
# Out:
# 2026 Rank             object
# Previous Rank         object
# Institution Name      object
# Country/Territory     object
# Region                object
# Size                  object
# Focus                 object
# Research              object
# Status                object
# AR SCORE             float64
# AR RANK               object
# ER SCORE             float64
# ER RANK               object
# FSR SCORE            float64
# FSR RANK              object
# CPF SCORE            float64
# CPF RANK              object
# IFR SCORE            float64
# IFR RANK              object
# ISR SCORE            float64
# ISR RANK              object
# ISD SCORE            float64
# ISD RANK              object
# IRN SCORE            float64
# IRN RANK              object
# EO SCORE             float64
# EO RANK               object
# SUS SCORE            float64
# SUS RANK              object
# Overall SCORE         object
# Filled_IRN_Score     float64
# dtype: object

# %% [markdown]
# ### Renaming columns

# %%
df.rename(columns={'Institution Name':'Institute Name'})
# Out:
#      2026 Rank Previous Rank                               Institute Name  \
# 0            1             1  Massachusetts Institute of Technology (MIT)
# 1            2             2                      Imperial College London
# 2            3             6                          Stanford University
# 3            4             3                         University of Oxford
# 4            5             4                           Harvard University
# ...        ...           ...                                          ...
# 1496     1401+     1201-1400                   University of West Bohemia
# 1497     1401+     1201-1400                    Voronezh State University
# 1498     1401+           NaN                          Walailak University
# 1499     1401+     1201-1400                         Yamaguchi University
# 1500     1401+     1201-1400                          Youngsan University
#
#              Country/Territory    Region Size Focus Research  \
# ...

# %% [markdown]
# ### change datatypes

# %%
df.dtypes
# Out:
# 2026 Rank             object
# Previous Rank         object
# Institution Name      object
# Country/Territory     object
# Region                object
# Size                  object
# Focus                 object
# Research              object
# Status                object
# AR SCORE             float64
# AR RANK               object
# ER SCORE             float64
# ER RANK               object
# FSR SCORE            float64
# FSR RANK              object
# CPF SCORE            float64
# CPF RANK              object
# IFR SCORE            float64
# IFR RANK              object
# ISR SCORE            float64
# ISR RANK              object
# ISD SCORE            float64
# ISD RANK              object
# IRN SCORE            float64
# IRN RANK              object
# EO SCORE             float64
# EO RANK               object
# SUS SCORE            float64
# SUS RANK              object
# Overall SCORE         object
# Filled_IRN_Score     float64
# dtype: object

# %%
df['New_SUS_Score'] = df['SUS SCORE'].astype(float)

# %%
df.head()
df.dtypes
# Out:
# 2026 Rank             object
# Previous Rank         object
# Institution Name      object
# Country/Territory     object
# Region                object
# Size                  object
# Focus                 object
# Research              object
# Status                object
# AR SCORE             float64
# AR RANK               object
# ER SCORE             float64
# ER RANK               object
# FSR SCORE            float64
# FSR RANK              object
# CPF SCORE            float64
# CPF RANK              object
# IFR SCORE            float64
# IFR RANK              object
# ISR SCORE            float64
# ISR RANK              object
# ISD SCORE            float64
# ISD RANK              object
# IRN SCORE            float64
# IRN RANK              object
# EO SCORE             float64
# EO RANK               object
# SUS SCORE            float64
# SUS RANK              object
# Overall SCORE         object
# Filled_IRN_Score     float64
# New_SUS_Score        float64
# ...

# %%
df['New_SUS_Score']
# Out:
# 0       93.8
# 1       98.3
# 2       95.4
# 3       77.9
# 4       77.8
#         ...
# 1496    19.5
# 1497    20.4
# 1498    43.0
# 1499    22.5
# 1500    11.5
# Name: New_SUS_Score, Length: 1501, dtype: float64

# %%
df['New_SUS_Score'] = df['New_SUS_Score'].apply(lambda x: x*2)
df['New_SUS_Score']
# Out:
# 0       187.6
# 1       196.6
# 2       190.8
# 3       155.8
# 4       155.6
#         ...
# 1496     39.0
# 1497     40.8
# 1498     86.0
# 1499     45.0
# 1500     23.0
# Name: New_SUS_Score, Length: 1501, dtype: float64

# %% [markdown]
# ### Data Aggregating and Grouping

# %%
## Grouping based on country and AR Score

grouped_AR_Score = df.groupby('Country/Territory')['AR SCORE'].mean().sort_values()
print(grouped_AR_Score)
# Out:
# Country/Territory
# Dominican Republic         3.950000
# Bosnia and Herzegovina     5.000000
# Guatemala                  6.500000
# Libya                      6.800000
# Paraguay                   7.600000
#                             ...
# Denmark                   50.840000
# Sweden                    51.712500
# Netherlands               55.769231
# Singapore                 56.850000
# Hong Kong SAR, China      57.755556
# Name: AR SCORE, Length: 106, dtype: float64

# %%
grouped_sum = df.groupby(['Country/Territory', 'Focus'])['AR SCORE'].sum()
print(grouped_sum)
# Out:
# Country/Territory                   Focus
# Argentina                           CO        33.8
#                                     FC       312.4
#                                     FO        37.3
#                                     SP        35.3
# Armenia                             CO         8.7
#                                              ...
# Venezuela (Bolivarian Republic of)  CO         9.8
#                                     FC        63.8
#                                     FO        53.1
# Viet Nam                            CO       121.7
#                                     FO        43.7
# Name: AR SCORE, Length: 287, dtype: float64

# %% [markdown]
# ### Aggregate multiple functions

# %%
grouped_agg = df.groupby('Region')['AR SCORE'].agg(['mean', 'sum', 'count'])
print(grouped_agg)
# Out:
#                mean      sum  count
# Region
# Africa    16.597872    780.1     47
# Americas  27.805866   9954.5    358
# Asia      21.890442  12368.1    565
# Europe    28.356674  13809.7    487
# Oceania   40.734091   1792.3     44

# %% [markdown]
# ### Merging and joining dataframes

# %%
df1 = pd.DataFrame({'Key': ['A', 'B', 'C'], 'Value1': [1,2,3]})
df2 = pd.DataFrame({'Key': ['A', 'B', 'D'], 'Value1': [4,5,6]})

# %%
df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Value1
# 0   A       4
# 1   B       5
# 2   D       6

# %%
## Merge dataframe on the 'Key' column

pd.merge(df1, df2, on="Key", how="inner")
# Out:
#   Key  Value1_x  Value1_y
# 0   A         1         4
# 1   B         2         5

# %%
pd.merge(df1, df2, on="Key", how="left")
# Out:
#   Key  Value1_x  Value1_y
# 0   A         1       4.0
# 1   B         2       5.0
# 2   C         3       NaN

# %%
pd.merge(df1, df2, on="Key", how="right")
# Out:
#   Key  Value1_x  Value1_y
# 0   A       1.0         4
# 1   B       2.0         5
# 2   D       NaN         6

# %%
pd.merge(df1, df2, on="Key", how="outer")
# Out:
#   Key  Value1_x  Value1_y
# 0   A       1.0       4.0
# 1   B       2.0       5.0
# 2   C       3.0       NaN
# 3   D       NaN       6.0
